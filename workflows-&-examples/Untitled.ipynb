# %%
import seaborn as sns
sns.set()

# %%
import matplotlib.pyplot as plt
% matplotlib inline

# %%
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
# Out:
# (-1.2142507666786346,
#  1.1347110779275069,
#  -1.1258468317413044,
#  1.1012308066577541)

# %%
data = {# Context distribution
        'EXONIC:0':22052,
        'EXONIC:1':20779,
        'EXONIC:2':21272,
        'INTERGENIC':1791031,
        'INTRONIC':1855819,
        'NON-CODING-EXONIC':90807}

# %%
labels = 'Coding exonic', 'Coding intronic', 'Noncoding', 'Intergenic'
sizes = [ data['EXONIC:0'] + data['EXONIC:1'] + data['EXONIC:2'],
          data['INTRONIC'],
          data['NON-CODING-EXONIC'],
          data['INTERGENIC'] ]
explode = (0.1, 0.01, 0.03, 0.05)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=0)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.


plt.savefig('context1.png', dpi=150)
plt.show()

# %%
labels = 'Phase 0', 'Phase 1', 'Phase 2'
sizes = [ data['EXONIC:0'], data['EXONIC:1'], data['EXONIC:2'] ]
explode = (0.01, 0.03, 0.02)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=0)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.


plt.savefig('context2.png', dpi=150)
plt.show()
